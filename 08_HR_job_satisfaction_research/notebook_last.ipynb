# %% [markdown]
# <div style="border:solid Chocolate 2px; padding: 40px">
#
# <b> Анна, привет!👋</b>
#
# Меня зовут Алексей Гриб, и я буду ревьюером твоего проекта.
#
# Сразу хочу предложить в дальнейшем общаться на "ты" - надеюсь, так будет комфортнее:) Но если это неудобно, обязательно дай знать, и мы придумаем что-нибудь ещё!
#
# Цель ревью - не искать ошибки в твоём проекте, а помочь тебе сделать твою работу ещё лучше, устранив недочёты и приблизив её к реальным задачам специалиста по работе с данными. Поэтому не расстраивайся, если что-то не получилось с первого раза - это нормально, и это поможет тебе вырасти!
#
# Ты можешь найти мои комментарии, обозначенные <font color='green'>зеленым</font>, <font color='gold'>желтым</font> и <font color='red'>красным</font> цветами, например:
#
# <br/>
#
# <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b> похвала, рекомендации «со звёздочкой», полезные лайфхаки, которые сделают и без того красивое решение ещё более элегантным.
# </div>
#
# <br/>
#
# <div class="alert alert-warning">
#     <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Некоторые замечания и рекомендации⚠️:</b> некритичные ошибки или развивающие рекомендации на будущее.
# </div>
#
#
# <br/>
# <div class="alert alert-block alert-danger">
# <h2> Комментарий ревьюера <a class="tocSkip"></h2>
#
#
# <b>На доработку❌:</b>
# Критичные ошибки, которые обязательно нужно исправить.
# </div>
#
#
# Пожалуйста, не удаляй мои комментарии, они будут особенно полезны для нашей работы в случае повторной проверки проекта.
#
# Ты также можешь задавать свои вопросы, реагировать на мои комментарии, делать пометки и пояснения - полная творческая свобода! Но маленькая просьба - пускай они будут отличаться от моих комментариев, это поможет избежать путаницы в нашем общении:)
# Например, вот так:
#
# <div class="alert alert-info">
# <h2> Комментарий студента <a class="tocSkip"> </h2>
#
# *твой текст*
# </div>
#
# Давай посмотрим на твой проект!

# %% [markdown]
# <div style="border:solid Chocolate 2px; padding: 40px">
#
# <b> Комментарий ревьюера </b>
#
# Анна, обрати внимание на ряд важных моментов:
#
# 1. При воспроизведении проекта возникла ошибка чтения файлов - они не были найдены по указанному пути. Если разработка проекта ведётся локально или в среде, отличной от среды Практикума - обязательно нужно предусматривать возможность загрузки файлов из разных источников. Платформа Практикума - имитация среды заказчика, в которой будет запускаться твоё решение, и тут очень важно предусмотреть момент воспроизводимости - будет не очень красиво, если заказчик не сможет пользоваться решением и увидит такую ошибку на демонстрации:)
#
# Для этого, например, можно использовать конструкцию `try-except`: сначала пробуешь локальный путь, при возникновении ошибки используется серверный путь (подробнее можешь почитать тут: https://pythonworld.ru/tipy-dannyx-v-python/isklyucheniya-v-python-konstrukciya-try-except-dlya-obrabotki-isklyuchenij.html).
#
# Но еще лучше использовать библиотеку `os` - её использование позволит тебе проверять существование указанных директорий (что может быть актуально при одновременной работа на локальном и сетевом окружении) и загружать данные из существующей директории, избегая ошибок. Как пример:
#
#     import os
#
#     pth1 = '/folder_1/data.csv'
#     pth2 = '/folder_2/data.csv'
#
#     if os.path.exists(pth1):
#         query_1 = pd.read_csv(pth1)
#     elif os.path.exists(pth2):
#         query_1 = pd.read_csv(pth2)
#     else:
#         print('Something is wrong')
#
# 2. Проект не закончен - нужно выполнить проект до конца по условию из брифа. По твоим вопросам:
#
# - `Не понятно зачем перебирать модели и параметры к ним, если значение метрики SMAPE на тестовой выборке получилось 11.74. Это удовлетворяет условию задачи? (<=15). Или нужно что-то еще? Прошу помощи, может что-то я далаю не так?`. Обычно исследуется несколько моделей, чтобы найти лучшее решение - в зависимости от задачи, данных и способа их обработки, а также настройки разных моделей результат для одной и той же задачи может быть разным. Наша цель - найти лучшую модель. Поэтому сначала мы для разных моделей оптимизируем гиперпараметры, получаем по ним промежуточную оценку на кросс-валидации, и уже эту лучшую модель оцениваем на `test`;
# - `Не понятно чем дополнить пайплайн? признаки все те же. quit перевела в численный.` - его нужно дополнить новым выходным признаком `job_satisfaction_rate`, добавить его нужно как в `train`, так и в `test` как предсказания лучшей модели из первой задачи.
#
# Если что-то нужно будет уточнить по вопросам - задавай вопросы, постараюсь ответить на следующей итерации:)
#
# Работу над проектом продолжим, когда все задания будут завершены.

# %% [markdown]
# <div style="border:solid Chocolate 2px; padding: 40px">
#
# <b> Комментарий ревьюера v.2 </b>
#
# Анна, теперь у нас проблемы с импортом библиотек - ты импортируешь `SHAP`, который отсутствует в базовом окружении Практикума. Чтобы твоё решение корректно воспроизводилось на платформе, этот модуль также нужно установить через `pip install`.

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b> Всё работает - поехали!

# %%
#!pip install -U scikit-learn

# %%
#!pip install scipy --upgrade

# %%
#!pip3 install numpy --upgrade

# %%
#pip install shap

# %%
#pip install phik

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import phik
import os
from sklearn.model_selection import train_test_split
from sklearn.metrics import roc_auc_score

# загружаем класс pipeline
from sklearn.pipeline import Pipeline

# загружаем классы для подготовки данных
from sklearn.preprocessing import OneHotEncoder, OrdinalEncoder, StandardScaler, MinMaxScaler
from sklearn.compose import ColumnTransformer

# загружаем класс для работы с пропусками
from sklearn.impute import SimpleImputer

# загружаем функцию для работы с метриками
from sklearn.metrics import fbeta_score, make_scorer

# импортируем класс GridSearchCV
from sklearn.model_selection import GridSearchCV


# загружаем нужные модели
from sklearn.linear_model import LogisticRegression
from sklearn.linear_model import LinearRegression
from sklearn.tree import DecisionTreeRegressor
from sklearn.datasets import make_classification
from sklearn.preprocessing import LabelEncoder
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import RandomForestRegressor
from sklearn.dummy import DummyRegressor


import shap

from IPython.core.display import display, HTML
display(HTML("<style>.container { width:95% !important; }</style>"))

import warnings
warnings.simplefilter(action='ignore')
# Out:
# Importing display from IPython.core.display is deprecated since IPython 7.14, please import from IPython display
# <style>.container { width:95% !important; }</style>

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b> Библиотеки импортировали - отлично!

# %% [markdown]
# # Самостоятельный проект: Сборный проект —2

# %% [markdown]
# # Описание проекта

# %% [markdown]
# HR-аналитики компании «Работа с заботой» помогают бизнесу оптимизировать управление персоналом: бизнес предоставляет данные, а аналитики предлагают, как избежать финансовых потерь и оттока сотрудников. В этом HR-аналитикам пригодится машинное обучение, с помощью которого получится быстрее и точнее отвечать на вопросы бизнеса.
#
# Компания предоставила данные с характеристиками сотрудников компании. Среди них — уровень удовлетворённости сотрудника работой в компании. Эту информацию получили из форм обратной связи: сотрудники заполняют тест-опросник, и по его результатам рассчитывается доля их удовлетворённости от 0 до 1, где 0 — совершенно неудовлетворён, 1 — полностью удовлетворён.
#
# Собирать данные такими опросниками не так легко: компания большая, и всех сотрудников надо сначала оповестить об опросе, а затем проследить, что все его прошли.

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b> Хорошее вступление!
#
# В нём есть всё, что необходимо, чтобы понять суть проекта с первых строк отчёта!

# %% [markdown]
# # Задача 1: предсказание уровня удовлетворённости сотрудника

# %% [markdown]
# ## Загрузка данных

# %% [markdown]
# Загрузите файлы с данными.
# Тренировочная выборка:

# %%
pth1 = 'train_job_satisfaction_rate.csv'
pth2 = '/datasets/train_job_satisfaction_rate.csv'

if os.path.exists(pth1):
    train_job_satisfaction_rate = pd.read_csv(pth1, sep=',', decimal='.')
elif os.path.exists(pth2):
    train_job_satisfaction_rate = pd.read_csv(pth2, sep=',', decimal='.')
else:
    print('Something is wrong') 
    
#train_job_satisfaction_rate = pd.read_csv('train_job_satisfaction_rate.csv', sep=',', decimal='.')
display(train_job_satisfaction_rate.sample(10))
display(train_job_satisfaction_rate.describe())
train_job_satisfaction_rate.info()

# %% [markdown]
# Есть пропуски в столбцах - debt (отдел, в котором работает сотрудник), level(уровень занимаемой должности). Типы данных определны верно. Данные в таблицах соответствуют описанию.

# %% [markdown]
# Загрузим таблицу с входные признаки тестовой выборки:

# %%
pth3 = 'test_features.csv'
pth4 = '/datasets/test_features.csv'

if os.path.exists(pth1):
    test_features = pd.read_csv(pth3, sep=',', decimal='.')
elif os.path.exists(pth2):
    test_features = pd.read_csv(pth4, sep=',', decimal='.')
else:
    print('Something is wrong') 
#test_features = pd.read_csv('test_features.csv', sep=',', decimal='.')
display(test_features.sample(10))
display(test_features.describe())
test_features.info()
# Out:
#           id        dept   level workload  employment_years last_year_promo  \
# 1073  757730       sales  middle   medium                 4              no
# 102   941823  purchasing  middle   medium                 5              no
# 326   150452       sales  middle   medium                 3              no
# 718   552444          hr  junior   medium                 2              no
# 1510  193643  purchasing  sinior   medium                10              no
# 1566  497886   marketing  junior   medium                 3              no
# 1749  162114       sales  middle      low                 5              no
# 1308  914306  technology  middle   medium                 7              no
# 1523  208312       sales  middle     high                 2              no
# 272   680340       sales  middle   medium                 2              no
#
#      last_year_violations  supervisor_evaluation  salary
# 1073                   no                      4   43200
# ...

# %% [markdown]
# В тестовой выборки также есть пропуски в столбцах - debt (отдел, в котором работает сотрудник), level(уровень занимаемой должности). Типы данных определны верно. Данные в таблицах соответствуют описанию.

# %% [markdown]
# Целевой признак тестовой выборки:

# %%
pth5 = 'test_target_job_satisfaction_rate.csv'
pth6 = '/datasets/test_target_job_satisfaction_rate.csv'

if os.path.exists(pth1):
    test_target_job_satisfaction_rate = pd.read_csv(pth5, sep=',', decimal='.')
elif os.path.exists(pth2):
    test_target_job_satisfaction_rate = pd.read_csv(pth6, sep=',', decimal='.')
else:
    print('Something is wrong') 
#test_target_job_satisfaction_rate = pd.read_csv('test_target_job_satisfaction_rate.csv', sep=',', decimal='.')
display(test_target_job_satisfaction_rate.sample(10))
print(test_target_job_satisfaction_rate.info())
test_target_job_satisfaction_rate.describe()
# Out:
#           id  job_satisfaction_rate
# 501   647058                   0.31
# 1793  742747                   0.69
# 1994  367507                   0.80
# 890   633920                   0.30
# 364   645627                   0.42
# 1410  762842                   0.19
# 246   757519                   0.68
# 923   991956                   0.65
# 603   783964                   0.57
# 1301  705199                   0.06
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2000 entries, 0 to 1999
# Data columns (total 2 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   id                     2000 non-null   int64
#  1   job_satisfaction_rate  2000 non-null   float64
# dtypes: float64(1), int64(1)
# memory usage: 31.4 KB
# None
#                   id  job_satisfaction_rate
# count    2000.000000             2000.00000
# mean   552765.213500                0.54878
# std    253851.326129                0.22011
# ...

# %% [markdown]
# Пропусков в таблицах нет. Типы данных определны верно. Данные в таблицах соответствуют описанию.

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b> Данные загружены. Здорово, что используешь `os` для загрузки файлов и управления путями к ним.

# %% [markdown]
# ## Предобработка данных

# %% [markdown]
# Проверим наличие явных дубликатов среди строк таблиц, чтобы исключить их влияние таких выбросов на модель классификации.

# %%
print('Найдено явных дубликатов:', train_job_satisfaction_rate.duplicated().sum())
# Out:
# Найдено явных дубликатов: 0

# %%
print('Найдено явных дубликатов:', test_features.duplicated().sum())
# Out:
# Найдено явных дубликатов: 0

# %%
print('Найдено явных дубликатов:', test_target_job_satisfaction_rate.duplicated().sum())
# Out:
# Найдено явных дубликатов: 0

# %% [markdown]
# Полных дубликатов в загруженных датасетах не выявлено

# %%
print('Количество уникальных ID:', len(train_job_satisfaction_rate['id'].unique()))
# Out:
# Количество уникальных ID: 4000

# %%
print('Количество уникальных ID:', len(test_features['id'].unique()))
# Out:
# Количество уникальных ID: 2000

# %%
print('Количество уникальных ID:', len(test_target_job_satisfaction_rate['id'].unique()))
# Out:
# Количество уникальных ID: 2000

# %% [markdown]
# Количество уникальных id соответствует количеству строк. Дубликатов id тоже не выявлено.

# %% [markdown]
# Проведем необходимую предобработку данных. Проверим уникальные значения категориальных признаков.

# %%
print(train_job_satisfaction_rate["dept"].unique())
print(train_job_satisfaction_rate["level"].unique())
print(train_job_satisfaction_rate["workload"].unique())
print(train_job_satisfaction_rate["last_year_promo"].unique())
print(train_job_satisfaction_rate["last_year_violations"].unique())
# Out:
# ['sales' 'hr' 'technology' 'purchasing' 'marketing' nan]
# ['junior' 'middle' 'sinior' nan]
# ['medium' 'high' 'low']
# ['no' 'yes']
# ['no' 'yes']

# %% [markdown]
# Исправим ошибку в слове sinior на senior

# %%
train_job_satisfaction_rate['level'] = train_job_satisfaction_rate['level'].replace('sinior', 'senior')
train_job_satisfaction_rate['level'].unique()
# Out:
# array(['junior', 'middle', 'senior', nan], dtype=object)

# %% [markdown]
# <div class="alert alert-warning">
#     <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Некоторые замечания и рекомендации⚠️:</b> Тут мы видим синтаксическую ошибку в `sinior` - можно было бы поправить этот момент.

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера v.2 <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b> Учтено.

# %% [markdown]
# Выведем строки со значением Nan

# %%
train_job_satisfaction_rate[train_job_satisfaction_rate["dept"].isnull() | train_job_satisfaction_rate["level"].isnull()].sort_values(by='dept')
# Out:
#           id   dept   level workload  employment_years last_year_promo  \
# 1209  631073  sales     NaN   medium                 1              no
# 1469  416327  sales     NaN      low                 1              no
# 1745  135043  sales     NaN   medium                 1              no
# 2522  998838  sales     NaN   medium                 1              no
# 1526  694746    NaN  junior   medium                 5              no
# 1630  814624    NaN  junior   medium                 3              no
# 1633  475114    NaN  junior     high                 4              no
# 2781  497243    NaN  junior   medium                 1              no
# 2975  168668    NaN  junior      low                 3              no
# 3866  641150    NaN  junior      low                 3              no
#
#      last_year_violations  supervisor_evaluation  salary  \
# 1209                   no                      4   27600
# 1469                   no                      5   18000
# ...

# %%
print(test_features["dept"].unique())
print(test_features["level"].unique())
print(test_features["workload"].unique())
print(test_features["last_year_promo"].unique())
print(test_features["last_year_violations"].unique())
# Out:
# ['marketing' 'hr' 'sales' 'purchasing' 'technology' nan ' ']
# ['junior' 'middle' 'sinior' nan]
# ['medium' 'low' 'high' ' ']
# ['no' 'yes']
# ['no' 'yes']

# %% [markdown]
# Аналогично, исправим ошибку.

# %%
test_features['level'] = test_features['level'].replace('sinior', 'senior')
test_features['level'].unique()
# Out:
# array(['junior', 'middle', 'senior', nan], dtype=object)

# %% [markdown]
# <div class="alert alert-warning">
#     <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Некоторые замечания и рекомендации⚠️:</b> А здесь у нас явно кривые значения в `dept` и `level` - тоже можно блыо бы прокомментировать.

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера v.2 <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b> Учтено.

# %% [markdown]
# В таблице в слотбцах debt и level выявлены пропуски nan, а также пустые сроки ' '. Выведем эти сроки в таблице.

# %%
test_features[test_features["dept"].isnull() | test_features["level"].isnull() | (test_features["dept"]==' ') | (test_features["workload"]==' ')].sort_values(by='dept')
# Out:
#           id       dept   level workload  employment_years last_year_promo  \
# 1699  822186             middle   medium                 3              no
# 15    590867  marketing  junior                          4              no
# 312   471990      sales     NaN      low                 1              no
# 191   609865        NaN  junior   medium                 1              no
# 1196  832342        NaN  junior   medium                 1              no
#
#      last_year_violations  supervisor_evaluation  salary
# 1699                   no                      4   38400
# 15                     no                      4   28800
# 312                    no                      3   12000
# 191                    no                      1   20400
# 1196                   no                      4   28800

# %% [markdown]
# Все имеющиеся пропуски заполним в пайплайне.

# %% [markdown]
# <div class="alert alert-warning">
#     <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Некоторые замечания и рекомендации⚠️:</b> Функция не используется - в целом нет необходимости её держать.

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера v.2 <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b> Учтено.

# %% [markdown]
# ## Исследовательский анализ данных

# %% [markdown]
# Распределим признаки на числовые десятичные, числовые целые и категироальне

# %%
float_col_names = ['job_satisfaction_rate', 
                  'salary']

int_col_names = ['employment_years',
                 'supervisor_evaluation']

cat_col_names = ['dept',
                'level',
                'workload',
                'last_year_promo',
                'last_year_violations']

# %%
for name in int_col_names:
    fig, axes = plt.subplots(2, 1, figsize=(8, 10))
    sns.countplot(data = train_job_satisfaction_rate, x = name, alpha=0.5, ax=axes[0]);
    axes[0].set_title('Столбчатая диаграмма')
    sns.boxplot(data=train_job_satisfaction_rate, x=name, ax=axes[1])
    axes[1].set_title('Разброс значений признаков')

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b> В целом дискретные признаки можно аналитизровать и с помощью пирога, а вот искать в них выбросы иногда может быть не лучшей затеей:)

# %%
fig, axes = plt.subplots(2, 1, figsize=(8,10))
sns.histplot(data = train_job_satisfaction_rate, x='salary', bins=20, alpha=0.5, ax=axes[0])
axes[0].set_title('Гистограмма распределения')
sns.boxplot(data=train_job_satisfaction_rate, x='salary', ax=axes[1])
axes[1].set_title('Разброс значений признаков');

# %% [markdown]
# Построим графики, которые описывают категориальные признаки.

# %%
for name in cat_col_names:
    train_job_satisfaction_rate[name].value_counts().plot(kind='pie', autopct='%1.1f%%', shadow=True, 
                legend=True, title=f'Соотношение по признаку {name}', ylabel='', labeldistance=None)
    plt.legend(bbox_to_anchor=(1, 0, 0.5, 1), loc="center left")
    plt.show()

# %% [markdown]
# Проведем аналогичный анализ для тестовых данных.

# %%
for name in int_col_names:
    fig, axes = plt.subplots(2, 1, figsize=(8, 10))
    sns.countplot(data = test_features, x = name, alpha=0.5, ax=axes[0]);
    axes[0].set_title('Столбчатая диаграмма')
    sns.boxplot(data=test_features, x=name, ax=axes[1])
    axes[1].set_title('Разброс значений признаков')

# %%
fig, axes = plt.subplots(2, 1, figsize=(8,10))
sns.histplot(data = test_features, x='salary', bins=20, alpha=0.5, ax=axes[0])
axes[0].set_title('Гистограмма распределения')
sns.boxplot(data=test_features, x='salary', ax=axes[1])
axes[1].set_title('Разброс значений признаков')
# Out:
# Text(0.5, 1.0, 'Разброс значений признаков')

# %%
for name in cat_col_names:
    test_features[name].value_counts().plot(kind='pie', autopct='%1.1f%%', shadow=True, 
                legend=True, title=f'Соотношение по признаку {name}', ylabel='', labeldistance=None)
    plt.legend(bbox_to_anchor=(1, 0, 0.5, 1), loc="center left")
    plt.show()

# %% [markdown]
# Большая часть коллектива задействована в продажах - около 40%, по другим департаментам более равномерное от 10% до 20%. Соотношение по должностям  в обеих датасетах выглядит логичным: Джуниоров - 48%, Мидлов - 43%, Синьоров - 9%.
#
# Большинство сотрудников оценивают свою нагрузку как среднюю - 50%, 30%  - считают ее низкой, и около 20% - высокой.
#
# Доля сотрудников, получивших повышение выглядит довольно низкой - всего 3%, а доля сотрудников нарушивших трудовой договор за последний год, наоборот довольно высокой - до 14%.

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b> Исследовали распределение признаков - отлично!

# %% [markdown]
# <div class="alert alert-block alert-danger">
# <h2> Комментарий ревьюера <a class="tocSkip"></h2>
#
#
# <b>На доработку❌:</b> Не хватает анализа корреляции выборок - `train` и `test`.
#
# Отмечу, что матрица корреляций Пирсона не подходит для анализа датасетов, в которых присутствуют категориальные или дискретные признаки - по ним корреляций Пирсона не может быть оценена вообще (в случае категориальных) или не может быть оценена корректно (в случае дискретных).
#
# Хорошим решением будет использование матрицы `phik` - она анализирует корреляцию между признаками любого типа и не требует предварительного кодирования. При использовании `phik` крайне важно настроить параметр `interval_cols`, передав ему список с названиями непрерывных признаков: если этого не сделать, библиотека своими силами будет пытаться разнести признаки по типам, и она часто делает в этом ошибки - от этого в свою очередь мы получаем некорректную оценку корреляций, так как от типа признака зависит метод оценки корреляции.
#
# Познакомиться с этой корреляцией можно тут: на английском: https://towardsdatascience.com/phik-k-get-familiar-with-the-latest-correlation-coefficient-9ba0032b37e7, на русском: https://dzen.ru/a/ZEtcuc4K2RX_Jstr?utm_referer=www.google.com.

# %% [markdown]
# Построем матрицу корреляции для всего датасета.

# %%
train_matrix = train_job_satisfaction_rate.drop(['id'], axis=1).phik_matrix(interval_cols=['job_satisfaction_rate', 'salary'])

# %%
test_marrix = test_features.drop(['id'], axis=1).phik_matrix(interval_cols=['job_satisfaction_rate', 'salary'])

# %% [markdown]
# <div class="alert alert-block alert-danger">
# <h2> Комментарий ревьюера v.2 <a class="tocSkip"></h2>
#
#
# <b>На доработку❌:</b> `employment_years` - дискретный признак, в `interval_cols` передавать не нужно.

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера v.3 <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b> Учтено.

# %%
fig, axes = plt.subplots(1, 2, figsize=(22, 12))  
sns.heatmap(train_matrix, annot=True, fmt='.2f', cmap='bwr', ax=axes[0]) 
axes[0].set_title('Тренировочная выборка')
sns.heatmap(test_marrix, annot=True, fmt='.2f', cmap='bwr', ax=axes[1])
axes[1].set_title('Входные признаки');

# %% [markdown]
# Наибольшая положительная корреляция между ежемесячной зарплатой сотрудника и уровнем занимаемой должности, а также загруженностью сотрудника, уровень удовлетворённости сотрудника работой (целевой признак) коррелирует с оценкой качества работы сотрудника.
#
# Также имеется умеренная корреляция между: зарплатой и длительностью работы в компании, уровнем удовлетворённости сотрудника работой и нарушениями сотрудником трудового договора, длительностью работы в компании  и уровнем занимаемой должности.

# %% [markdown]
# ## Подготовка данных

# %% [markdown]
# Подготовку признаков выполним в пайплайне, дополнив пайплайн шага предобработки. При кодировании учитывайте особенности признаков и моделей и используйте как минимум два кодировщика.

# %%
RANDOM_STATE = 42

# %% [markdown]
# Будем использованием id в качестве индекса. Для начала объединим тестовые данные, затем установим id индесами.

# %%
test_features_job_satisfaction_rate = pd.merge(test_features, test_target_job_satisfaction_rate, how='inner', on='id')

# %%
train_job_satisfaction_rate = train_job_satisfaction_rate.set_index('id')
test_features_job_satisfaction_rate = test_features_job_satisfaction_rate.set_index('id')

# %% [markdown]
# Поверим наличие новых дубликатов в данных train: так как мы удалили часть признаков, у нас могут появиться новые явные дубликаты, которые могут навредить.

# %%
print('Найдено явных дубликатов:', train_job_satisfaction_rate.duplicated().sum())
# Out:
# Найдено явных дубликатов: 245

# %%
train_job_satisfaction_rate = train_job_satisfaction_rate.drop_duplicates()

# %%
#X_train = train_job_satisfaction_rate.drop(['job_satisfaction_rate', 'id'], axis=1)
X_train = train_job_satisfaction_rate.drop(['job_satisfaction_rate'], axis=1)
y_train = train_job_satisfaction_rate['job_satisfaction_rate']
#X_test = test_features.drop(['id'], axis=1)
X_test = test_features_job_satisfaction_rate.drop(['job_satisfaction_rate'], axis=1)
y_test = test_features_job_satisfaction_rate['job_satisfaction_rate']

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b> Выделили признаки для обучения и целевые признаки - отлично!
# </div>

# %% [markdown]
# <div class="alert alert-warning">
#     <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Некоторые замечания и рекомендации⚠️:</b> Хорошим решением было бы использованием `id` в качестве индекса: с одной стороны, это позволит не использовать признак в моделировании, с другой - мы сможем обратиться к нему через `.index` при необходимости.

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера v.2 <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b> Учтено.

# %% [markdown]
# <div class="alert alert-block alert-danger">
# <h2> Комментарий ревьюера <a class="tocSkip"></h2>
#
#
# <b>На доработку❌:</b>
#
# 1. После удаления `id` нужно проверить наличие новых дубликатов в данных: так как мы удалили часть лишних признаков, у нас могут появиться новые явные дубликаты: чем меньше признаков остаётся, тем выше шанс, что значения остальных признаков будут пересекаться. При этом ценности для модели такие наблюдения уже не принесут, поэтому стоит проверить дубликаты также в финальной версии таблицы.
#
# При этом важно проверить только `train`: наличие дубликатов в `test` нам никак не мешает, но это правильное решение с точки зрения неприкосновенности `test`, ведь реальный поток данных (который имитирует `test` выборка) мы исправить не сможем. А вот наличие дубликатов в `train` не только не принесёт пользы модели, но может и навредить.
#
# 2. `X_test` и `y_test` перед разделением обязательно нужно соединить по `id`, чтобы не было возможных ошибок, связанных с несовпадением порядка наблюдений;

# %% [markdown]
# <div class="alert alert-block alert-danger">
# <h2> Комментарий ревьюера v.2 <a class="tocSkip"></h2>
#
#
# <b>На доработку❌:</b> При соединении обязательно нужно указать `id` в качестве ключа, чтобы соединение было выполнено корректно.

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера v.3 <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b> Учтено.

# %%
X_train.shape, X_test.shape, y_train.shape, y_test.shape
# Out:
# ((3755, 8), (2000, 8), (3755,), (2000,))

# %% [markdown]
# Cоздаём списки с названиями признаков

# %%
ohe_columns = ['dept',
               'last_year_promo',
               'last_year_violations']
ord_columns = ['level',
                'workload']
num_columns = ['salary',
               'employment_years',
               'supervisor_evaluation']

# %% [markdown]
# Создаём пайплайн для подготовки признаков из списка ohe_columns

# %%
ohe_pipe = Pipeline([('simpleImputer_before_ohe', SimpleImputer(missing_values=np.nan, strategy='most_frequent')),
                     ('ohe', OneHotEncoder(drop='first',
                                           sparse=False, 
                                           handle_unknown='ignore'
                                          ))])

# %% [markdown]
# Создаём пайплайн для подготовки признаков из списка ord_columns

# %%
ord_pipe = Pipeline(
    [('simpleImputer_before_ord', SimpleImputer(missing_values=np.nan, strategy='most_frequent')),
     ('ord',  OrdinalEncoder(
                categories=[['junior', 'middle', 'sinior'],
                            ['low', 'medium', 'high']], 
                handle_unknown='use_encoded_value',
                unknown_value=np.nan
            )
        ),
     ('simpleImputer_after_ord', SimpleImputer(missing_values=np.nan, strategy='most_frequent'))
    ]
)

# %% [markdown]
# Cоздаём общий пайплайн для подготовки данных

# %%
data_preprocessor = ColumnTransformer(
    [
        ('ohe', ohe_pipe, ohe_columns),
        ('ord', ord_pipe, ord_columns),
        ('num', StandardScaler(), num_columns)
    ], 
    remainder='passthrough'
)

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b> Здорово, что используешь сочетание `ColumnTransformer` и `Pipeline` для соединения разных инструментов в единый модельный объект и настраиваешь бесперебойную работу энкодера в случае появления в данных новых, неизвестных на момент обучения значений признаков - так твоё решение будет более гибким и масштабируемым.

# %% [markdown]
# Cоздаём итоговый пайплайн: подготовка данных и модель

# %%
pipe_final = Pipeline([
    ('preprocessor', data_preprocessor),
    ('models', LinearRegression())
])

# %%
param_grid = [
    # словарь для модели LinearRegression() 
    {
        'models': [LinearRegression()],
        'preprocessor__num': [StandardScaler(), MinMaxScaler(), 'passthrough']   
    },
 
    # словарь для модели DecisionTreeRegressor()
    {
        'models': [DecisionTreeRegressor(random_state=RANDOM_STATE)],
#        'models__max_depth': range(2, 3),
#        'models__max_features': range(2, 5),
        'preprocessor__num': [StandardScaler(), MinMaxScaler(), 'passthrough']  
    },
    # словарь для модели RandomForestRegressor()
     {
        'models': [RandomForestRegressor(random_state=RANDOM_STATE)],
        'models__max_depth': range(6, 10),
        'models__max_features': range(6, 10),
        'preprocessor__num': [StandardScaler(), MinMaxScaler(), 'passthrough']  
    }
]

# %%
def smape(y_true, y_pred):
     return 100/len(y_true) * np.sum(2 * np.abs(y_pred - y_true) / (np.abs(y_true) + np.abs(y_pred)))

# %%
smape_scorer = make_scorer(score_func=smape, greater_is_better=False)

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b> Есть функция для оценки `sMAPE`, а также пользовательский скорринг для кросс-валидации - супер!
# </div>

# %% [markdown]
# <div class="alert alert-block alert-danger">
# <h2> Комментарий ревьюера <a class="tocSkip"></h2>
#
#
# <b>На доработку❌:</b>
# В функции есть арифметическая ошибка, занижающая значение метрики. Рекомендую разбить длинную строку на промежуточные действия и сохранять их в переменные - так найти ошибку будет проще.

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера v.2 <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b> Учтено.

# %%
grid_search = GridSearchCV(
    pipe_final,
    param_grid,
    n_jobs=-1,
    cv=5,
    scoring=smape_scorer
)
grid_search.fit(X_train, y_train)
# Out:
# /Users/annakhabarova/anaconda3/envs/practicum/lib/python3.9/site-packages/sklearn/preprocessing/_encoders.py:975: FutureWarning: `sparse` was renamed to `sparse_output` in version 1.2 and will be removed in 1.4. `sparse_output` is ignored unless you leave `sparse` to its default value.
#   warnings.warn(
# /Users/annakhabarova/anaconda3/envs/practicum/lib/python3.9/site-packages/sklearn/preprocessing/_encoders.py:975: FutureWarning: `sparse` was renamed to `sparse_output` in version 1.2 and will be removed in 1.4. `sparse_output` is ignored unless you leave `sparse` to its default value.
#   warnings.warn(
# /Users/annakhabarova/anaconda3/envs/practicum/lib/python3.9/site-packages/sklearn/preprocessing/_encoders.py:975: FutureWarning: `sparse` was renamed to `sparse_output` in version 1.2 and will be removed in 1.4. `sparse_output` is ignored unless you leave `sparse` to its default value.
#   warnings.warn(
# ...

# %%
print('Лучшая модель и её параметры:\n\n', grid_search.best_estimator_)
print ('Метрика лучшей модели на кросс-валидации:', grid_search.best_score_*-1)
# Out:
# Лучшая модель и её параметры:
#
#  Pipeline(steps=[('preprocessor',
#                  ColumnTransformer(remainder='passthrough',
#                                    transformers=[('ohe',
#                                                   Pipeline(steps=[('simpleImputer_before_ohe',
#                                                                    SimpleImputer(strategy='most_frequent')),
#                                                                   ('ohe',
#                                                                    OneHotEncoder(drop='first',
#                                                                                  handle_unknown='ignore',
#                                                                                  sparse=False))]),
#                                                   ['dept', 'last_year_promo',
#                                                    'last_year_violations']),
#                                                  ('ord',
# ...

# %%
print('Метрика лучшей модели на тренировочной  выборке:', round(smape_scorer(grid_search, X_train, y_train), 2)*-1)
# Out:
# Метрика лучшей модели на тренировочной  выборке: 12.92

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b> Исследовано несколько алгоритмов, проведён подбор гиперпараметров с помощью `GridSearchCV`, выполнена промежуточная оценка моделей на кросс-валидации - молодец!

# %% [markdown]
# <div class="alert alert-warning">
#     <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Некоторые замечания и рекомендации⚠️:</b> Обрати внимание, что оценка получена на кросс-валидации, а не на `train` выборке - очень важно корректно разделять эти сущности.

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера v.2 <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b> Учтено.

# %% [markdown]
# Проверим на тестовй выборке. Критерий успеха: SMAPE ≤15на тестовой выборке.

# %%
y_pred = grid_search.predict(X_test)

# %%
print('Метрика лучшей модели на тестовой  выборке:', round(smape_scorer(grid_search, X_test, y_test), 2)*-1)
# Out:
# Метрика лучшей модели на тестовой  выборке: 14.36

# %% [markdown]
# Критерий соответствует требуемому.

# %% [markdown]
# <div class="alert alert-success">
#
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b> Лучшую модель оценили на `test` - отличный результат!

# %% [markdown]
# <div class="alert alert-warning">
#     <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Некоторые замечания и рекомендации⚠️:</b>
# Очень важно также проверить лучшую модель на адекватность, сравнив качество её предсказаний с качеством модели, которая предсказывала бы константу - вдруг окажется, что не было бы большого смысла заниматься созданием новых признаков, тюнингом и кросс-валидацией моделей, если можно было бы просто предсказывать среднее значение тренировочной выборки?
#
# В качестве константной модели можно использовать `DummyRegressor` (https://scikit-learn.org/stable/modules/generated/sklearn.dummy.DummyRegressor.html) -  эта модель как раз создана для генерирования константных предсказаний.
#
# Важно, чтобы результат тестирования нашей модели на тествой выборке был лучше, чем результат константной модели - в противном случае наша модель является бесполезной, так как все наши усилия над проектом не принесли результата, а можель, просто предсказывющая среднее на `train`, делает нашу работу лучше.

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера v.2 <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b> Учтено.

# %% [markdown]
# ## Оформление выводов

# %%
dummy_regr = DummyRegressor(strategy="mean")

# %%
dummy_regr.fit(X_train, y_train)
y_pred = dummy_regr.predict(X_test)
dummy_regr.score(y_test,y_pred)
smape(y_test, y_pred)
# Out:
# 38.26225790202238

# %% [markdown]
# **ВЫВОД:** В результате автоматизированного поиска гиперпараметров с помощью GridSearchCV получили лучшую модель RandomForestRegressor(с гиперпараметрами max_depth=9, max_features=9), другие модели показали более высокий показатель SMAPE.
#
# Сравнив качество предсказаний с качеством модели, которая предсказывала константу - среднее значение, убедились, что полученная модель граздо лучше предсказывает целевой показатель.

# %% [markdown]
# <div class="alert alert-success">
#
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b> На данном этапе всё - только оценка на `test` лучшей модели, опционально - оценка её адекватности с помошью константной модели.

# %% [markdown]
# <div class="alert alert-block alert-danger">
# <h2> Комментарий ревьюера <a class="tocSkip"></h2>
#
#
# <b>На доработку❌:</b>
# Обязательно нужен вывод по результатам машинного обучения: как минимум нужно сделать вывод о лучшей модели и её метрике на `test`, дополнительно можно описать метрики других моделей на кросс-валидации, чтобы было понятно, из чего выбиралась лучшая.

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера v.2 <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b> Учтено.

# %% [markdown]
# <div class="alert alert-warning">
#     <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Некоторые замечания и рекомендации⚠️:</b>
#
# Здесь заканчивается стрктурный блок работы - стоит сделать промежуточные выводы о проделанной работе в блоке.

# %% [markdown]
# # Задача 2: предсказание увольнения сотрудника из компании

# %% [markdown]
# ## Загрузка данных

# %% [markdown]
# Тренировочная выборка:

# %%
pth7 = 'train_quit.csv'
pth8 = '/datasets/train_quit.csv'

if os.path.exists(pth1):
    train_quit = pd.read_csv(pth7, sep=',', decimal='.')
elif os.path.exists(pth2):
    train_quit = pd.read_csv(pth8, sep=',', decimal='.')
else:
    print('Something is wrong') 

#train_quit = pd.read_csv('train_quit.csv', sep=',', decimal='.')
display(train_quit.sample(10))
display(train_quit.describe())
train_quit.info()
# Out:
#           id        dept   level workload  employment_years last_year_promo  \
# 3169  174417  technology  junior     high                 2              no
# 2311  342563  technology  junior   medium                 1              no
# 2112  836552   marketing  junior   medium                 1              no
# 745   344001   marketing  middle      low                 3             yes
# 1631  231895          hr  middle     high                 6              no
# 329   615793       sales  junior   medium                 1              no
# 3659  194774  purchasing  junior     high                 1              no
# 3911  819087   marketing  sinior     high                 7              no
# 2776  796157          hr  middle   medium                 8              no
# 3354  331788  technology  sinior      low                 2              no
#
#      last_year_violations  supervisor_evaluation  salary quit
# 3169                   no                      5   38400   no
# ...

# %% [markdown]
# Входные признаки тестовой выборки те же, что и в прошлой задаче - грузитьиз не будем повторною
#
# Целевой признак тестовой выборки:

# %%
pth9 = 'test_target_quit.csv'
pth10 = '/datasets/test_target_quit.csv'

if os.path.exists(pth1):
    test_target_quit = pd.read_csv(pth9, sep=',', decimal='.')
elif os.path.exists(pth2):
    test_target_quit = pd.read_csv(pth10, sep=',', decimal='.')
else:
    print('Something is wrong') 

#test_target_quit = pd.read_csv('test_target_quit.csv', sep=',', decimal='.')
display(test_target_quit.sample(10))
display(test_target_quit.describe())
test_target_quit.info()
# Out:
#           id quit
# 403   372661   no
# 4     416898  yes
# 187   431446   no
# 1056  179244   no
# 109   530417  yes
# 1078  228280   no
# 225   948968  yes
# 559   418655   no
# 375   211409   no
# 1550  308241   no
#                   id
# count    2000.000000
# mean   552765.213500
# std    253851.326129
# min    100298.000000
# 25%    339052.000000
# 50%    550793.000000
# 75%    765763.750000
# max    999029.000000
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2000 entries, 0 to 1999
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   id      2000 non-null   int64
#  1   quit    2000 non-null   object
# dtypes: int64(1), object(1)
# memory usage: 31.4+ KB

# %% [markdown]
# Пропусков в таблицах нет. Типы данных определны верно. Данные в таблицах соответствуют описанию.

# %% [markdown]
# ## Предобработка данных

# %%
print('Найдено явных дубликатов:', train_quit.duplicated().sum())
# Out:
# Найдено явных дубликатов: 0

# %%
print('Найдено явных дубликатов:', test_target_quit.duplicated().sum())
# Out:
# Найдено явных дубликатов: 0

# %% [markdown]
# Полных дубликатов в загруженных датасетах не выявлено

# %%
print('Количество уникальных ID:', len(train_quit['id'].unique()))
# Out:
# Количество уникальных ID: 4000

# %%
print('Количество уникальных ID:', len(test_target_quit['id'].unique()))
# Out:
# Количество уникальных ID: 2000

# %% [markdown]
# Количество уникальных id соответствует количеству строк. Дубликатов id тоже не выявлено.

# %% [markdown]
# Проведем необходимую предобработку данных. Проверим уникальные значения категориальных признаков.

# %%
print(train_quit["dept"].unique())
print(train_quit["level"].unique())
print(train_quit["workload"].unique())
print(train_quit["last_year_promo"].unique())
print(train_quit["last_year_violations"].unique())
# Out:
# ['sales' 'purchasing' 'marketing' 'technology' 'hr']
# ['middle' 'junior' 'sinior']
# ['high' 'medium' 'low']
# ['no' 'yes']
# ['no' 'yes']

# %%
train_quit['level'] = train_quit['level'].replace('sinior', 'senior')
train_quit['level'].unique()
# Out:
# array(['middle', 'junior', 'senior'], dtype=object)

# %% [markdown]
# Пропусков и пробелов нет

# %% [markdown]
# ## Исследовательский анализ данных

# %%
float_col_names = ['salary']

int_col_names = ['employment_years',
                 'supervisor_evaluation']

cat_col_names = train_job_satisfaction_rate.select_dtypes(include='object').columns.tolist()

# %%
sns.histplot(train_quit, x='salary', hue='quit', bins=20, stat='density', common_norm=False, alpha=0.5).set(title='Гистограмма распределения Зарплаты')
plt.show()

# %% [markdown]
# <div class="alert alert-block alert-danger">
# <h2> Комментарий ревьюера <a class="tocSkip"></h2>
#
#
# <b>На доработку❌:</b>
# При анализе распределения признака в разрезе оттока нужно использовать нормированную гистограмму (например, `shs.histplot()` с параметрами `stat='density', common_norm=False` или `sns.kdeplot()`): гистограммы такого типа позволяют нивелировать разницу в размерах выборок при анализе распределений. Обрати также внимание, что при использовании нормированных гистограмм по оси Y будет уже не частота значений, а плотность распределения.

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера v.2 <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b> Учтено.

# %%
for name in int_col_names:
    fig, ax = plt.subplots(figsize=(8, 8))
    sns.barplot(data=train_quit, x=name, y='quit', alpha=0.5).set(title='Столбчатая диаграмма')

# %% [markdown]
# Чаще увольняются сотрудники, проработавшие не более 2х лет и с невысокой оценкой руководства.

# %% [markdown]
# <div class="alert alert-block alert-danger">
# <h2> Комментарий ревьюера <a class="tocSkip"></h2>
#
#
# <b>На доработку❌:</b>
# В случае дискретных/категориальных признаков также может быть проблема несбалансированности выборок, когда выборка ушедших работников меньше выборки неушедших - анализ абсолютных значений не будет информативным.
#
# Полезно будет анализировать, например, долю ушедших работников в каждом значении признака - например, с помощью `sns.barplot`, передав в `x` исследуемый признак, а в `y` - признак увольнения.
#
# Однако по аналогии с первой задачей можно анализировать распредедение признака в целом без деления на отток по аналогии с первой задачей - тут выбор за тобой.

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера v.2 <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b> Учтено.

# %%
# относительное количество наблюдений удобно вывести с параметром normalize = True
#sns.barplot(data=train_quit, x=train_quit['level'], y=train_quit['quit'].value_counts(normalize = True), alpha=0.5).set(title='Столбчатая диаграмма');

# %% [markdown]
# <div class="alert alert-block alert-danger">
# <h2> Комментарий ревьюера v.2 <a class="tocSkip"></h2>
#
#
# <b>На доработку❌:</b>
# График пустой.

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера v.3 <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b> Учтено.

# %%
for name in cat_col_names:
    fig = plt.subplots(1, 1, figsize=(6, 6))
    sns.countplot(data = train_quit, x = name, hue = 'quit', alpha=0.5).set(title='Столбчатая диаграмма')

# %% [markdown]
# <div class="alert alert-success">
#
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b> Есть EDA новой `train` выборки.

# %%
train_quit_matrix = train_quit.drop(['id'], axis=1).phik_matrix(interval_cols=['job_satisfaction_rate', 'salary'])

# %% [markdown]
# <div class="alert alert-block alert-danger">
# <h2> Комментарий ревьюера v.2 <a class="tocSkip"></h2>
#
#
# <b>На доработку❌:</b> Аналогично по `employment_years`.

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера v.3 <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b> Учтено.

# %%
fig, ax = plt.subplots(figsize=(10, 10)) 
sns.heatmap(train_quit_matrix, annot=True, fmt='.2f', cmap='bwr').set(title='Тренировочная выборка');

# %% [markdown]
# Признаки коррелируют аналогично.
# Наибольшая корреляция между уровнем удовлетворённости сотрудника работой в компании  и оценкой качества работы сотрудника и нарушениями сотрудника. Также есть коррелиция между зарплатой сотрудника и уровнем занимаемой должности, а также загруженностью сотрудника.
#
# Также имеется корреляция между: зарплатой и уровнем занимаемой должности, нагрузкой, длительностью работы в компании.

# %% [markdown]
# <div class="alert alert-block alert-danger">
# <h2> Комментарий ревьюера <a class="tocSkip"></h2>
#
#
# <b>На доработку❌:</b>
# 1. Не хватает корреляции для новой `train` выборки.
#
# 2. По результатам EDA не сделан вывод.

# %% [markdown]
# <div class="alert alert-success">
#
# <h2> Комментарий ревьюера v.2 <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b> Учтено.

# %% [markdown]
# Составим портрет «уволившегося сотрудника».

# %%
train_quit['quit'].value_counts(normalize=True)
# Out:
# quit
# no     0.718
# yes    0.282
# Name: proportion, dtype: float64

# %%
_columns=['quit',
          'dept',
          'last_year_promo',
          'last_year_violations',
          'level',
          'workload'
]

# %%
sns.set(font_scale=1.4)
for name in _columns:
    train_quit[name].value_counts(normalize=True).plot(kind='bar', figsize=(7, 6), rot=45)
    plt.title(f"Соотношение по признку {name}", y=1.02)
    plt.ylabel('Доля')
    plt.xlabel('Значение признака')
    plt.show()

# %% [markdown]
# Увольняется 25% процентов сотрудников, т.е. каждый четвертый - это очень высокая текучка кадров.
#
# Наибольшее количество уволившихся из отдела продаж - 30%, среднего звена - 50%, оценивающих свою нагрузку как среднюю, уволившиеся не получали повышения - 95%, но при этом не нарушали трудовой договор за последний год - 81%

# %%
salary_pivot = np.round(pd.pivot_table(train_quit, index=['level', 'quit'],
                              aggfunc={'salary': 'mean',
                                       'employment_years': 'mean', 
                                       #'job_satisfaction_rate': 'mean', 
                                       'supervisor_evaluation': 'mean', 
                                       'quit': 'count',}), 2)
salary_pivot.columns = ['mean_employment_years', 
                        #'mean_job_satisfaction_rate',  
                        'quit_num', 
                        'mean_salary',
                        'mean_supervisor_evaluation']
salary_pivot
# Out:
#              mean_employment_years  quit_num  mean_salary  \
# level  quit
# junior no                     2.18       946     25661.73
#        yes                    1.63      1003     22508.08
# middle no                     5.36      1586     40075.91
#        yes                    3.39       108     33122.22
# senior no                     6.37       340     60130.59
#        yes                    4.71        17     46447.06
#
#              mean_supervisor_evaluation
# level  quit
# junior no                          3.96
#        yes                         3.02
# middle no                          3.48
#        yes                         3.25
# senior no                          3.51
#        yes                         3.47

# %%
salary_pivot.plot(kind = 'bar', y='mean_salary', figsize=(8,6))
salary_pivot.plot(kind = 'bar', y='quit_num', figsize=(8,6))

plt.show()

# %% [markdown]
# Чаще всего увольняются с позиции Джун - более 50%. В других отделах доля уволившихся в пределах нормы (не более 14% в год).
# Вне зависимости от должности ЗП у уволившихся сотрудников ниже (на 10% - Джун, на 20% - Мидл, на 25% - Синьор), так же уволившиеся сотрудники меньше времени проработали в компании по стравнению с оставшимися сотрудниками в аналогичной должности.
# Логично, что уровень удовлетворенности у уволившися ниже, как и оценка руководителя. Оба эти показателя зависят от занимаемой должности и более высоких позицих разница меньше.
#
# Портрет уволившего сотрудника такой: Джун с ЗП до 24 тыс., проработавший в компании до 2х лет, с низким уровенем удовлетворённости и низкой оценкой качества работы руководителем.

# %% [markdown]
# <div class="alert alert-success">
#
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b> Есть анализ портрета работника в разрезе признака ухода - отлично! Хорошее решение - сравнивать средние по непрерывному признаку зарплаты.

# %% [markdown]
# <div class="alert alert-block alert-danger">
# <h2> Комментарий ревьюера <a class="tocSkip"></h2>
#
#
# <b>На доработку❌:</b> Анализ категориальных/дискретных признаков нужно сделать с помощью относительных величин - оперировать абсолютными величинами не всегда удобно, так как в зависимости от масштаба исследования (компания на 100 человек и компания на 100 000 человек, например) результаты могут быть более или менее интерпретируемыми. Мы можем использовать `value_counts(normalize=True)`.

# %% [markdown]
# <div class="alert alert-info">
# <h2> Комментарий студента <a class="tocSkip"> </h2>
#
# Не понятно к какой части проекта коментарий про `value_counts(normalize=True)`
# </div>

# %% [markdown]
# <div class="alert alert-block alert-danger">
# <h2> Комментарий ревьюера v.2 <a class="tocSkip"></h2>
#
#
# <b>На доработку❌:</b> К анализу портрета клиента. Категориальные/дискретные признаки нужно проанализировать с помощью относительных значений - в этом может помочь инструмент из комментария выше.
#
# Проанализировать при этом важно все признаки.

# %% [markdown]
# <div class="alert alert-block alert-danger">
# <h2> Комментарий ревьюера v.3 <a class="tocSkip"></h2>
#
#
# <b>На доработку❌:</b> Не учтено - анализ относительных показателей должен быть проведён по всем категориальным/дискретным признакам. В сводной таблице посчитано среднее - это не то, что требуется.

# %% [markdown]
# <div class="alert alert-success">
#
# <h2> Комментарий ревьюера v.4 <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b> Учтено.

# %% [markdown]
# Аналитики утверждают, что уровень удовлетворённости сотрудника работой в компании влияет на то, уволится ли сотрудник.
#
# Проверим это утверждение: визуализируем и сравним распределения признака job_satisfaction_rate для ушедших и оставшихся сотрудников. Будем использовать данные с обоими целевыми признаками тестовой выборки.

# %%
targets = pd.merge(test_target_quit, test_target_job_satisfaction_rate, how='inner', on='id')
targets.sample(10)
# Out:
#           id quit  job_satisfaction_rate
# 587   124064   no                   0.31
# 309   560948  yes                   0.40
# 480   535156  yes                   0.69
# 853   523719  yes                   0.62
# 755   959945   no                   0.63
# 1020  412563   no                   0.76
# 1583  875033   no                   0.78
# 1260  952457   no                   0.62
# 1822  347370   no                   0.41
# 233   418490  yes                   0.60

# %%
fig, axes = plt.subplots(2, 1, figsize=(10,12))
sns.histplot(data = targets, x='job_satisfaction_rate', hue='quit', stat='density', common_norm=False, bins=20, alpha=0.5, ax=axes[0])
axes[0].set_title('Гистограмма распределения')
sns.boxplot(data=targets, x='job_satisfaction_rate', y='quit', ax=axes[1])
axes[1].set_title('Разброс значений признакa');

# %%
satisfaction_rate = pd.pivot_table(targets, index='quit', values='job_satisfaction_rate', aggfunc='mean')
satisfaction_rate
# Out:
#       job_satisfaction_rate
# quit
# no                 0.612040
# yes                0.387713

# %% [markdown]
# Уровень удовлетворенности уволившихся сотрудников (38,8%) значительно ниже  уровня удовлетворенности оставшихся - 62,2%, который тоже нельзя считать надежным.

# %% [markdown]
# <div class="alert alert-success">
#
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b> Исследовано распределение удовлетворённости в зависимости от факта ухода.

# %% [markdown]
# <div class="alert alert-warning">
#     <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Некоторые замечания и рекомендации⚠️:</b> Чуть более интересным решением, позволяющим выполнить оценку не "на глаз", а более статистически достоверно, было бы использование статистического теста (например, `ttest`) для сравнения распределений в выборках.

# %% [markdown]
# <div class="alert alert-block alert-danger">
# <h2> Комментарий ревьюера <a class="tocSkip"></h2>
#
#
# <b>На доработку❌:</b> Здесь мы имеем дело с непрерывной величиной - для анализа её распределения стоит использовать нормированную гистограмму (например, `shs.histplot()` с параметрами `stat='density', common_norm=False` или `sns.kdeplot()`): гистограммы такого типа позволяют нивелировать разницу в размерах выборок при анализе распределений. Обрати также внимание, что при использовании нормированных гистограмм по оси Y будет уже не частота значений, а плотность распределения.
# </div>

# %% [markdown]
# <div class="alert alert-success">
#
# <h2> Комментарий ревьюера v.2 <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b> Учтено.

# %% [markdown]
# ## Добавление нового входного признака

# %% [markdown]
# Добавим job_satisfaction_rate, предсказанный лучшей моделью первой задачи, к входным признакам второй задачи. Для этого  нужно использовать обученную ранее модель регрессии и подать в нее признаки выборки для классификации (убрав целевой признак). Затем создать новый столбец и присвоить в него массив с полученными предсказаниями.

# %%
test_features = pd.merge(test_features, test_target_quit, how='inner', on='id')

# %% [markdown]
# <div class="alert alert-block alert-danger">
# <h2> Комментарий ревьюера <a class="tocSkip"></h2>
#
#
# <b>На доработку❌:</b> Кодирование нельзя делать руками:
# - при появлении новых значений категориальных признаков, не предусмотренных твоим решением, модель или упадёт, или будет генерировать ошибки;
# - такое решение не сделаешь частью `pipeline`, а все современные решения базируются на них.
#
# Поэтому кодирование нужно делать только с применением обучаемых трансформеров. Для кодирования целевого признака нужно использовать `LabelEncoder` (https://scikit-learn.org/stable/modules/generated/sklearn.preprocessing.LabelEncoder.html).

# %% [markdown]
# <div class="alert alert-success">
#
# <h2> Комментарий ревьюера v.2 <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b> Учтено.

# %%
train_quit['job_satisfaction_rate'] = grid_search.predict(train_quit.drop(['quit', 'id'], axis=1))
test_features['job_satisfaction_rate'] = grid_search.predict(test_features.drop(['quit', 'id'], axis=1))

# %% [markdown]
# <div class="alert alert-success">
#
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b> Ввели новый признак на основе предсказания модли из прошлой задачи.

# %% [markdown]
# ## Подготовка данных

# %%
train_quit = train_quit.set_index('id')

# %%
test_features = test_features.set_index('id')

# %%
print('Найдено явных дубликатов:', train_quit.duplicated().sum())
# Out:
# Найдено явных дубликатов: 1413

# %%
train_quit = train_quit.drop_duplicates()

# %%
X_train_new = train_quit.drop(['quit'], axis=1)
y_train_new = train_quit['quit']
X_test_new = test_features.drop(['quit'], axis=1)
y_test_new = test_features['quit']

X_train_new.shape, X_test_new.shape, y_train_new.shape, y_test_new.shape
# Out:
# ((2587, 9), (2000, 9), (2587,), (2000,))

# %% [markdown]
# <div class="alert alert-block alert-danger">
# <h2> Комментарий ревьюера <a class="tocSkip"></h2>
#
#
# <b>На доработку❌:</b> Аналогично по дубликатам.

# %% [markdown]
# <div class="alert alert-success">
#
# <h2> Комментарий ревьюера v.2 <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b> Учтено.

# %% [markdown]
# Подготовим признаки так же, как и в первой задаче: выполним подготовку в пайплайне, дополнив пайплайн предобработки. При кодировании учтем особенности признаков и моделей и используем как минимум два кодировщика.

# %%
ohe_columns = ['dept',
               'last_year_promo',
               'last_year_violations']
ord_columns = ['level',
                'workload']
num_columns = ['salary',
               'employment_years',
               'supervisor_evaluation',
               'job_satisfaction_rate'
               ]

# %%
label_encoder = LabelEncoder()
y_train_new = label_encoder.fit_transform(y_train_new)
y_test_new = label_encoder.transform(y_test_new)

# %% [markdown]
# Создаём пайплайн для подготовки признаков из списка ohe_columns

# %%
ohe_pipe = Pipeline([('simpleImputer_before_ohe', SimpleImputer(missing_values=np.nan, strategy='most_frequent')),
                     ('ohe', OneHotEncoder(drop='first',
                                           sparse=False, 
                                           handle_unknown='ignore'
                                          ))])

# %% [markdown]
# Создаём пайплайн для подготовки признаков из списка ord_columns

# %%
ord_pipe = Pipeline(
    [('simpleImputer_before_ord', SimpleImputer(missing_values=np.nan, strategy='most_frequent')),
     ('ord',  OrdinalEncoder(
                categories=[['junior', 'middle', 'sinior'],
                            ['low', 'medium', 'high']], 
                handle_unknown='use_encoded_value',
                unknown_value=np.nan
            )
        ),
     ('simpleImputer_after_ord', SimpleImputer(missing_values=np.nan, strategy='most_frequent'))
    ]
)

# %% [markdown]
# Cоздаём общий пайплайн для подготовки данных

# %%
data_preprocessor = ColumnTransformer(
    [
        ('ohe', ohe_pipe, ohe_columns),
        ('ord', ord_pipe, ord_columns),
        ('num', StandardScaler(), num_columns)
    ], 
    remainder='passthrough'
)

# %% [markdown]
# Cоздаём итоговый пайплайн: подготовка данных и модель

# %%
pipe_final = Pipeline([
    ('preprocessor', data_preprocessor),
    ('models', LogisticRegression(random_state=RANDOM_STATE))
])

# %% [markdown]
# ## Обучение модели

# %% [markdown]
# Обучим три модели, подберем гиперпараметры и проверим качество лучшей модели.

# %%
#from sklearn.ensemble import RandomForestClassifier

# %% [markdown]
# <div class="alert alert-warning">
#     <h2> Комментарий ревьюера v.2 <a class="tocSkip"> </h2>
#
# <b>Некоторые замечания и рекомендации⚠️:</b>
# Все библиотеки стоит импортировать в начале проекта - таким образом получатель твоего отчёта сможет узнать о проблемах с его окружением сразу перед работой с проектом, а не посреди или в конце проекта.

# %% [markdown]
# <div class="alert alert-success">
#
# <h2> Комментарий ревьюера v.2 <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b> Учтено.

# %%
param_grid = [
    # словарь для модели LogisticRegression() 
    {
        'models': [LogisticRegression(random_state=RANDOM_STATE)],
        'preprocessor__num': [StandardScaler(), MinMaxScaler(), 'passthrough']   
    },
 
    # словарь для модели DecisionTreeClassifier()
    {
        'models': [DecisionTreeClassifier(random_state=RANDOM_STATE)],
        'models__max_depth': range(2, 5),
        'models__max_features': range(5, 7),
        'preprocessor__num': [StandardScaler(), MinMaxScaler(), 'passthrough']  
    },
    
    {
        'models': [RandomForestClassifier(random_state=RANDOM_STATE)],
        'models__max_depth': range(2, 5),
        'models__max_features': range(5, 7),
        'preprocessor__num': [StandardScaler(), MinMaxScaler(), 'passthrough']  
    }
]

# %% [markdown]
# <div class="alert alert-block alert-danger">
# <h2> Комментарий ревьюера <a class="tocSkip"></h2>
#
#
# <b>На доработку❌:</b> У `LogisticRegression` не задан `random_state`.

# %% [markdown]
# <div class="alert alert-block alert-danger">
# <h2> Комментарий ревьюера v.2 <a class="tocSkip"></h2>
#
#
# <b>На доработку❌:</b> Не учтено выше при создании `pipe_final`.

# %% [markdown]
# <div class="alert alert-success">
#
# <h2> Комментарий ревьюера v.2 <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b> Учтено.

# %%
grid_search = GridSearchCV(
    pipe_final,
    param_grid,
    n_jobs=-1,
    cv=5,
    scoring='roc_auc'
)
grid_search.fit(X_train_new, y_train_new)
# Out:
# /Users/annakhabarova/anaconda3/envs/practicum/lib/python3.9/site-packages/sklearn/preprocessing/_encoders.py:975: FutureWarning: `sparse` was renamed to `sparse_output` in version 1.2 and will be removed in 1.4. `sparse_output` is ignored unless you leave `sparse` to its default value.
#   warnings.warn(
# /Users/annakhabarova/anaconda3/envs/practicum/lib/python3.9/site-packages/sklearn/preprocessing/_encoders.py:975: FutureWarning: `sparse` was renamed to `sparse_output` in version 1.2 and will be removed in 1.4. `sparse_output` is ignored unless you leave `sparse` to its default value.
#   warnings.warn(
# /Users/annakhabarova/anaconda3/envs/practicum/lib/python3.9/site-packages/sklearn/preprocessing/_encoders.py:975: FutureWarning: `sparse` was renamed to `sparse_output` in version 1.2 and will be removed in 1.4. `sparse_output` is ignored unless you leave `sparse` to its default value.
#   warnings.warn(
# ...

# %%
print('Лучшая модель и её параметры:\n\n', grid_search.best_estimator_)
print ('Метрика лучшей модели на тренировочной выборке:', grid_search.best_score_)
# Out:
# Лучшая модель и её параметры:
#
#  Pipeline(steps=[('preprocessor',
#                  ColumnTransformer(remainder='passthrough',
#                                    transformers=[('ohe',
#                                                   Pipeline(steps=[('simpleImputer_before_ohe',
#                                                                    SimpleImputer(strategy='most_frequent')),
#                                                                   ('ohe',
#                                                                    OneHotEncoder(drop='first',
#                                                                                  handle_unknown='ignore',
#                                                                                  sparse=False))]),
#                                                   ['dept', 'last_year_promo',
#                                                    'last_year_violations']),
#                                                  ('ord',
# ...

# %% [markdown]
# Проверим на тестовй выборке. Критерий успеха: ROC-AUC ≥ 0.91 на тестовой выборке.

# %% [markdown]
# <div class="alert alert-success">
#
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b> Лучшая модель выбрана.

# %%
y_pred = grid_search.predict_proba(X_test_new)

# %%
print('Метрика лучшей модели на тестовой  выборке:', roc_auc_score(y_test_new, y_pred[:,1]))
# Out:
# Метрика лучшей модели на тестовой  выборке: 0.9190879412868685

# %% [markdown]
# <div class="alert alert-block alert-danger">
# <h2> Комментарий ревьюера <a class="tocSkip"></h2>
#
#
# <b>На доработку❌:</b>
#
# Давай вспомним, что из себя представляет метрика `AUC-ROC` и подходит ли метод `predict` для её оценки?

# %% [markdown]
# <div class="alert alert-success">
#
# <h2> Комментарий ревьюера v.2 <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b> Учтено.

# %% [markdown]
# Полученная метрика соотвествует трубуему критерию. Попробуем улучшить метрику за счет отбора признаков.

# %% [markdown]
# <div class="alert alert-info">
# <h2> Комментарий студента <a class="tocSkip"> </h2>
#
# Далее, наверное, необязательная часть, но оставлю на усмотрение ревьюера
# </div>

# %% [markdown]
# <div class="alert alert-success">
#
# <h2> Комментарий ревьюера v.2 <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b> Да, оценка значимости - необязательная часть, но раз она есть в проекте - тоже будет проверена:)

# %% [markdown]
# <div class="alert alert-block alert-danger">
# <h2> Комментарий ревьюера <a class="tocSkip"></h2>
#
#
# <b>На доработку❌:</b>
#
# Далее код снова упал с ошибкой - нужно устранить их и закончить активности в проекте.

# %% [markdown]
# <div class="alert alert-success">
#
# <h2> Комментарий ревьюера v.2 <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b> Учтено.

# %%
best_model = grid_search.best_estimator_
model = best_model.named_steps['models']
model
# Out:
# RandomForestClassifier(max_depth=4, max_features=5, random_state=42)

# %%
X_train_new_processed = best_model.named_steps['preprocessor'].fit_transform(X_train_new)
X_test_new_processed = best_model.named_steps['preprocessor'].transform(X_test_new)

# %%
explainer = shap.Explainer(model.predict_proba, X_train_new_processed)
shap_values = explainer(X_test_new_processed)
# Out:
# PermutationExplainer explainer: 2001it [09:46,  3.38it/s]

# %% [markdown]
# Проведем отбор признаков чтобы улучшить метрику.

# %%
features_out = best_model.named_steps['preprocessor'].get_feature_names_out().tolist()
features_out
# Out:
# ['ohe__dept_marketing',
#  'ohe__dept_purchasing',
#  'ohe__dept_sales',
#  'ohe__dept_technology',
#  'ohe__last_year_promo_yes',
#  'ohe__last_year_violations_yes',
#  'ord__level',
#  'ord__workload',
#  'num__salary',
#  'num__employment_years',
#  'num__supervisor_evaluation',
#  'num__job_satisfaction_rate']

# %%
fig, ax = plt.gcf(), plt.gca()
ax.tick_params(labelsize=14)
ax.set_title('Важность признаков', fontsize=20)
ax.set_ylabel("Признаки", fontsize=16)
shap.summary_plot(shap_values[:, :, 1], X_test_new_processed, plot_type="bar", feature_names=features_out)
plt.show()

# %% [markdown]
# <div class="alert alert-block alert-danger">
# <h2> Комментарий ревьюера v.2 <a class="tocSkip"></h2>
#
#
# <b>На доработку❌:</b>
#
# Тут и далее нужно подписать ось Y, а также название.

# %% [markdown]
# <div class="alert alert-success">
#
# <h2> Комментарий ревьюера v.3 <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b> Учтено.

# %% [markdown]
# <div class="alert alert-block alert-danger">
# <h2> Комментарий ревьюера v.3 <a class="tocSkip"></h2>
#
#
# <b>На доработку❌:</b>
#
# Код упал с ошибкой.

# %% [markdown]
# <div class="alert alert-success">
#
# <h2> Комментарий ревьюера v.4 <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b> Учтено.

# %%
fig, ax = plt.gcf(), plt.gca()
ax.tick_params(labelsize=14)
ax.set_title('Важность признаков', fontsize=20)
ax.set_ylabel("Признаки", fontsize=16)
shap.plots.beeswarm(shap_values[:, :, 1], max_display=12)

# %% [markdown]
# <div class="alert alert-info">
# <h2> Комментарий студента <a class="tocSkip"> </h2>
#
# У меня работает 🤷🏻‍♀️
#     ![%D0%A1%D0%BD%D0%B8%D0%BC%D0%BE%D0%BA%20%D1%8D%D0%BA%D1%80%D0%B0%D0%BD%D0%B0%202023-12-15%20%D0%B2%2022.15.08.png](attachment:%D0%A1%D0%BD%D0%B8%D0%BC%D0%BE%D0%BA%20%D1%8D%D0%BA%D1%80%D0%B0%D0%BD%D0%B0%202023-12-15%20%D0%B2%2022.15.08.png)
# </div>

# %% [markdown]
# <div class="alert alert-success">
#
# <h2> Комментарий ревьюера v.4 <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b> Иногда окружение платформы может приводить к таким ошибкам, сейчас всё отработало корректно.

# %% [markdown]
# <div class="alert alert-block alert-danger">
# <h2> Комментарий ревьюера v.2 <a class="tocSkip"></h2>
#
#
# <b>На доработку❌:</b>
#
# `Feature n` - не очень понятное название для признака, их в таком виде нельзя интерпретировать.

# %% [markdown]
# <div class="alert alert-success">
#
# <h2> Комментарий ревьюера v.3 <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b> Учтено.

# %% [markdown]
# Исключим наименее значимые признаки.

# %%
ohe_columns = ['last_year_promo',
               'last_year_violations']
ord_columns = ['level',
                'workload']
num_columns = ['salary', 
               'supervisor_evaluation',
               'employment_years',
              'job_satisfaction_rate']

# %%
X_train_new_sorted = train_quit.drop(['quit', 'dept'], axis=1)
X_test_new_sorted = test_features.drop(['quit', 'dept'], axis=1)
X_train_new_sorted.shape, X_test_new_sorted.shape, y_train_new.shape, y_test_new.shape
# Out:
# ((2587, 8), (2000, 8), (2587,), (2000,))

# %%
ohe_pipe = Pipeline([('simpleImputer_before_ohe', SimpleImputer(missing_values=np.nan, strategy='most_frequent')),
                     ('ohe', OneHotEncoder(drop='first',
                                           sparse=False, 
                                           handle_unknown='ignore'
                                          ))])

# %%
ord_pipe = Pipeline(
    [('simpleImputer_before_ord', SimpleImputer(missing_values=np.nan, strategy='most_frequent')),
     ('ord',  OrdinalEncoder(
                categories=[
                    ['junior', 'middle', 'sinior'],
                    ['low', 'medium', 'high']
                           ], 
                handle_unknown='use_encoded_value',
                unknown_value=np.nan
            )
        ),
     ('simpleImputer_after_ord', SimpleImputer(missing_values=np.nan, strategy='most_frequent'))
    ]
)

# %%
data_preprocessor_ = ColumnTransformer(
    [
        ('ohe', ohe_pipe, ohe_columns),
        ('ord', ord_pipe, ord_columns),
        ('num', MinMaxScaler(), num_columns)
    ], 
    remainder='passthrough'
)

# %%
pipe_final_ = Pipeline([
    ('preprocessor', data_preprocessor_),
    ('models', LogisticRegression(random_state=RANDOM_STATE))
])

# %% [markdown]
# ROC-AUC отлично подходит для бинарной классификации с несбалансированной выборкой.¶

# %%
grid_search = GridSearchCV(
    pipe_final_,
    param_grid,
    n_jobs=-1,
    cv=5,
    scoring='roc_auc'
)
grid_search.fit(X_train_new_sorted, y_train_new)
# Out:
# /Users/annakhabarova/anaconda3/envs/practicum/lib/python3.9/site-packages/sklearn/preprocessing/_encoders.py:975: FutureWarning: `sparse` was renamed to `sparse_output` in version 1.2 and will be removed in 1.4. `sparse_output` is ignored unless you leave `sparse` to its default value.
#   warnings.warn(
# /Users/annakhabarova/anaconda3/envs/practicum/lib/python3.9/site-packages/sklearn/preprocessing/_encoders.py:975: FutureWarning: `sparse` was renamed to `sparse_output` in version 1.2 and will be removed in 1.4. `sparse_output` is ignored unless you leave `sparse` to its default value.
#   warnings.warn(
# /Users/annakhabarova/anaconda3/envs/practicum/lib/python3.9/site-packages/sklearn/preprocessing/_encoders.py:975: FutureWarning: `sparse` was renamed to `sparse_output` in version 1.2 and will be removed in 1.4. `sparse_output` is ignored unless you leave `sparse` to its default value.
#   warnings.warn(
# ...

# %%
param_grid = [
    {
        'models': [LogisticRegression(random_state=RANDOM_STATE)],
        'preprocessor__num': [StandardScaler(), MinMaxScaler(), 'passthrough']   
    },
    {
        'models': [DecisionTreeClassifier(random_state=RANDOM_STATE)],
        'models__max_depth': range(6, 8),
        'models__max_features': range(7, 9),
        'preprocessor__num': [StandardScaler(), MinMaxScaler(), 'passthrough']  
    },    
    {
        'models': [RandomForestClassifier(random_state=RANDOM_STATE)],
        'models__max_depth': range(6, 7),
        'models__max_features': range(4, 9),
        'preprocessor__num': [StandardScaler(), MinMaxScaler(), 'passthrough']  
    }
]

# %% [markdown]
# <div class="alert alert-block alert-danger">
# <h2> Комментарий ревьюера v.2 <a class="tocSkip"></h2>
#
#
# <b>На доработку❌:</b> У `LogisticRegression` не задан `random_state`.

# %% [markdown]
# <div class="alert alert-block alert-danger">
# <h2> Комментарий ревьюера v.3 <a class="tocSkip"></h2>
#
#
# <b>На доработку❌:</b> Не учтено.

# %% [markdown]
# <div class="alert alert-success">
#
# <h2> Комментарий ревьюера v.4 <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b> Учтено.

# %%
print('Лучшая модель и её параметры:\n\n', grid_search.best_estimator_)
print ('Метрика лучшей модели на тренировочной выборке:', grid_search.best_score_)
# Out:
# Лучшая модель и её параметры:
#
#  Pipeline(steps=[('preprocessor',
#                  ColumnTransformer(remainder='passthrough',
#                                    transformers=[('ohe',
#                                                   Pipeline(steps=[('simpleImputer_before_ohe',
#                                                                    SimpleImputer(strategy='most_frequent')),
#                                                                   ('ohe',
#                                                                    OneHotEncoder(drop='first',
#                                                                                  handle_unknown='ignore',
#                                                                                  sparse=False))]),
#                                                   ['last_year_promo',
#                                                    'last_year_violations']),
#                                                  ('ord',
# ...

# %%
y_pred = grid_search.predict_proba(X_test_new_sorted)

# %%
print('Метрика лучшей модели на тестовой  выборке:', roc_auc_score(y_test_new, y_pred[:,1]))
# Out:
# Метрика лучшей модели на тестовой  выборке: 0.920230051956775

# %% [markdown]
# Метрику оценки качества в этой задаче удалось немного улучшить.

# %% [markdown]
# <div class="alert alert-success">
#
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b> Выше прокомментировал.

# %% [markdown]
# ## Выводы

# %% [markdown]
# На первом этапе по каждой задаче загрузили данные. Типы данных определны верно. Данные в таблицах соответствуют описанию. Выявлены пропуски в столбцах - debt (отдел, в котором работает сотрудник), level(уровень занимаемой должности).
# Дубликатов а данных не выявлено.  Проверили уникальные значения категориальных признаков
#
# Большая часть коллектива задействована в продажах - около 40%, по другим департаментам более равномерное распределение от 10% до 20%. Соотношение по должностям в обеих датасетах выглядит логичным: Джуниоров - 48%, Мидлов - 43%, Синьоров - 9%.
#
# Большинство сотрудников оценивают свою нагрузку как среднюю - 50%, 30% - считают ее низкой, и около 20% - высокой.
#
# Доля сотрудников, получивших повышение выглядит довольно низкой - всего 3%, а доля сотрудников нарушивших трудовой договор за последний год, наоборот довольно высокой - до 14%.
#
# Для снижения уровня увольнения среди сотрудников можно рекомендовать увеличить ЗП на позициях Мидлов и Синьоров до 41 и 60 тыс соответственно.
#
# Сотрудникам позицин Джун давать возможность раскрыться, т.е. давать больше нагрузки - workload, поощрять со стороны руководста - supervisor_evaluation, стимулировать к росту в там числе и по зарплате.

# %% [markdown]
# <div class="alert alert-success">
#
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b> Есть небольшой итоговый вывод - отлично!

# %% [markdown]
# <div class="alert alert-block alert-danger">
# <h2> Комментарий ревьюера <a class="tocSkip"></h2>
#
#
# <b>На доработку❌:</b>
#
# По результатам проделанной работы нужно сформировать рекомендации для сокращения уровня увольнений среди сотрудников.

# %% [markdown]
# <div class="alert alert-success">
#
# <h2> Комментарий ревьюера v.2 <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b> Учтено.

# %% [markdown]
# <div style="border:solid Chocolate 2px; padding: 40px">
#
# # Комментарий ревьюера: общий вывод по проекту.
#
# Анна, проект получился на довольно хорошем уровне - отличная работа над проектом, молодец!
#
# Мне нравится твой аналитический подход к выполнению проекта, ты соблюдаешь структуру работы, выполняешь её последовательно - это очень хорошо! Шаги проекта выполнены по порядку согласно плану проекта, нет смысловых и структурных ям. Важно, что не забываешь про выводы.
#
# Работа с моделями также выполнена отлично: исследовано несколько алгоритмов, проведён подбор гиперпараметров с помощью `GridSearchCV`, выполнена промежуточная оценка моделей на кросс-валидации - молодец! Здорово, что используешь сочетание `ColumnTransformer` и `Pipeline` для соединения разных инструментов в единый модельный объект и настраиваешь бесперебойную работу энкодера в случае появления в данных новых, неизвестных на момент обучения значений признаков - так твоё решение будет более гибким и масштабируемым.
#
# Над проектом ещё стоит поработать - есть рекомендации по дополнению некоторых твоих шагов проекта. Такие рекомендации я отметил жёлтыми комментариями. Будет здорово, если ты учтёшь их - так проект станет структурно и содержательно более совершенным.
#
# Также в работе есть критические замечания. К этим замечаниям я оставил пояснительные комментарии красного цвета, в которых перечислил возможные варианты дальнейших действий. Уверен, ты быстро с этим управишься:)
#
# Если о том, что нужно сделать в рамках комментариев, будут возникать вопросы - оставь их, пожалуйста, в комментариях, и я отвечу на них во время следующего ревью.
#
# Также буду рад ответить на любые твои вопросы по проекту или на какие-либо другие, если они у тебя имеются - оставь их в комментариях, и я постараюсь ответить:)
#
# Жду твой проект на повторном ревью. До встречи:)

# %% [markdown]
# <div style="border:solid Chocolate 2px; padding: 40px">
#
# # Комментарий ревьюера: общий вывод по проекту v.2.
#
# Анна, продолжаем работу над проектом - актуальные замечания отмечены комментариями с меткой `v.2`.
#
# Жду тебя снова:)

# %% [markdown]
# <div style="border:solid Chocolate 2px; padding: 40px">
#
# # Комментарий ревьюера: общий вывод по проекту v.3.
#
# Анна, продолжаем работу над проектом - актуальные замечания отмечены комментариями с меткой `v.3`.
#
# Жду тебя снова:)

# %% [markdown]
# <div style="border:solid Chocolate 2px; padding: 40px">
#
# # Комментарий ревьюера: общий вывод по проекту v.4.
#
# Анна, все замечания учтены - проект принят!
#
# Спасибо за хорошую работу над проектом, желаю успехов в дальнейшем обучении:)
